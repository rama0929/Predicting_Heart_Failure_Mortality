# %%
import pandas as pd

# %%
file_dir = 'C:\\Users\\abaez\\Desktop\\FinalProject'
heart_data_file = f'{file_dir}\\heart_failure_clinical_records_dataset.csv'

# %% [markdown]
# ## Convert the dataset into a dataframe.

# %%
heart_data_df = pd.read_csv(heart_data_file, low_memory=False)

# %% [markdown]
# ## Examine the first 5 rows of data

# %%
heart_data_df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %% [markdown]
# ## Examine the last 5 rows of data

# %%
heart_data_df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %% [markdown]
# ## Examine 5 random rows of data

# %%
heart_data_df.sample(n=5)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 254  53.0        1                       446         0                 60
# 221  65.0        0                       118         0                 50
# 111  55.0        0                        60         0                 35
# 124  60.0        0                       582         0                 40
# 109  45.0        0                       292         1                 35
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 254                    1  263358.03               1.0           139    1
# 221                    0  194000.00               1.1           145    1
# 111                    0  228000.00               1.2           135    1
# 124                    0  217000.00               3.7           134    1
# 109                    0  850000.00               1.3           142    1
#
#      smoking  time  DEATH_EVENT
# 254        0   215            0
# ...

# %% [markdown]
# ## Examine the columns in alphabetical order to make sure there are no duplicates.

# %%
sorted(heart_data_df.columns.tolist())
# Out:
# ['DEATH_EVENT',
#  'age',
#  'anaemia',
#  'creatinine_phosphokinase',
#  'diabetes',
#  'ejection_fraction',
#  'high_blood_pressure',
#  'platelets',
#  'serum_creatinine',
#  'serum_sodium',
#  'sex',
#  'smoking',
#  'time']

# %%
# There are no duplicate columns in this dataset that need to be cleaned.

# %% [markdown]
# ## Check for missing data

# %%
heart_data_df.isnull()
# Out:
#        age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    False    False                     False     False              False
# 1    False    False                     False     False              False
# 2    False    False                     False     False              False
# 3    False    False                     False     False              False
# 4    False    False                     False     False              False
# ..     ...      ...                       ...       ...                ...
# 294  False    False                     False     False              False
# 295  False    False                     False     False              False
# 296  False    False                     False     False              False
# 297  False    False                     False     False              False
# 298  False    False                     False     False              False
#
# ...

# %%
# Determine if there are any missing values in each column

heart_data_df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
# There is no missing data in any of the rows or columns.

# %% [markdown]
# ## Determine the data types in the DataFrame

# %%
heart_data_df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object
