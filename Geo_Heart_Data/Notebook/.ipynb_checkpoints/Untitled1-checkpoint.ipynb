# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("chronicdata.cdc.gov", None)

# Example authenticated client (needed for non-public datasets):
#client = Socrata("chronicdata.cdc.gov",
                #"LQGVHy6aGXfJugJhhgTPhOdEq",
                #userame="T.Ormanoski@gmail.com",
                #password="Zoey1446!")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("i2vk-mgdh", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.iloc[10:20]
# Out:
#     year locationabbr                     locationdesc geographiclevel  \
# 10  2014           AK                  Kenai Peninsula          County
# 11  2014           AK                Ketchikan Gateway          County
# 12  2014           AK                    Kodiak Island          County
# 13  2014           AK               Lake and Peninsula          County
# 14  2014           AK                Matanuska-Susitna          County
# 15  2014           AK                             Nome          County
# 16  2014           AK                      North Slope          County
# 17  2014           AK                 Northwest Arctic          County
# 18  2014           AK  Prince of Wales-Outer Ketchikan          County
# 19  2014           AK                            Sitka          County
#
#    datasource                    class                    topic data_value  \
# 10       NVSS  Cardiovascular Diseases  Heart Disease Mortality      299.4
# 11       NVSS  Cardiovascular Diseases  Heart Disease Mortality      326.8
# 12       NVSS  Cardiovascular Diseases  Heart Disease Mortality      274.8
# 13       NVSS  Cardiovascular Diseases  Heart Disease Mortality        387
# 14       NVSS  Cardiovascular Diseases  Heart Disease Mortality      244.7
# 15       NVSS  Cardiovascular Diseases  Heart Disease Mortality      378.8
# 16       NVSS  Cardiovascular Diseases  Heart Disease Mortality      327.4
# 17       NVSS  Cardiovascular Diseases  Heart Disease Mortality      338.3
# 18       NVSS  Cardiovascular Diseases  Heart Disease Mortality        NaN
# 19       NVSS  Cardiovascular Diseases  Heart Disease Mortality      261.9
#
#            data_value_unit                                    data_value_type  \
# 10  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 11  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 12  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 13  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 14  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 15  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 16  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 17  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 18  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 19  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#     ... stratification1 stratificationcategory2 stratification2 topicid  \
# 10  ...         Overall          Race/Ethnicity         Overall      T2
# 11  ...         Overall          Race/Ethnicity         Overall      T2
# 12  ...         Overall          Race/Ethnicity         Overall      T2
# 13  ...         Overall          Race/Ethnicity         Overall      T2
# 14  ...         Overall          Race/Ethnicity         Overall      T2
# 15  ...         Overall          Race/Ethnicity         Overall      T2
# 16  ...         Overall          Race/Ethnicity         Overall      T2
# 17  ...         Overall          Race/Ethnicity         Overall      T2
# 18  ...         Overall          Race/Ethnicity         Overall      T2
# 19  ...         Overall          Race/Ethnicity         Overall      T2
#
#    locationid                                         location_1  \
# 10      02122  {'latitude': '60.271254', 'longitude': '-151.5...
# 11      02130  {'latitude': '55.559161', 'longitude': '-131.3...
# 12      02150  {'latitude': '57.715045', 'longitude': '-153.8...
# 13      02164  {'latitude': '58.652287', 'longitude': '-156.1...
# 14      02170  {'latitude': '62.31628', 'longitude': '-149.60...
# 15      02180  {'latitude': '64.90346', 'longitude': '-163.94...
# 16      02185  {'latitude': '69.309889', 'longitude': '-153.3...
# 17      02188  {'latitude': '67.065111', 'longitude': '-159.7...
# 18      02201  {'latitude': '55.568424', 'longitude': '-131.6...
# 19      02220  {'latitude': '57.237666', 'longitude': '-135.2...
#
#    :@computed_region_bxsw_vy29 :@computed_region_he4y_prf8  \
# 10                          51                         NaN
# 11                          51                         111
# 12                          51                         112
# 13                          51                         113
# 14                          51                        1707
# 15                          51                         114
# 16                          51                         115
# 17                          51                         116
# 18                          51                         111
# 19                         NaN                         118
#
#    data_value_footnote_symbol data_value_footnote
# 10                        NaN                 NaN
# 11                        NaN                 NaN
# 12                        NaN                 NaN
# 13                        NaN                 NaN
# 14                        NaN                 NaN
# 15                        NaN                 NaN
# 16                        NaN                 NaN
# 17                        NaN                 NaN
# 18                          ~   Insufficient Data
# 19                        NaN                 NaN
#
# [10 rows x 21 columns]

# %%
results_df.tail(10)
# Out:
#       year locationabbr     locationdesc geographiclevel datasource  \
# 1990  2014           AR  Arkansas County          County       NVSS
# 1991  2014           AR    Ashley County          County       NVSS
# 1992  2014           AR    Baxter County          County       NVSS
# 1993  2014           AR     Boone County          County       NVSS
# 1994  2014           AR   Bradley County          County       NVSS
# 1995  2014           AR   Calhoun County          County       NVSS
# 1996  2014           AR   Carroll County          County       NVSS
# 1997  2014           AR    Chicot County          County       NVSS
# 1998  2014           AR     Clark County          County       NVSS
# 1999  2014           AR      Clay County          County       NVSS
#
#                         class                    topic data_value  \
# 1990  Cardiovascular Diseases  Heart Disease Mortality      645.4
# 1991  Cardiovascular Diseases  Heart Disease Mortality        688
# 1992  Cardiovascular Diseases  Heart Disease Mortality        NaN
# 1993  Cardiovascular Diseases  Heart Disease Mortality        NaN
# 1994  Cardiovascular Diseases  Heart Disease Mortality      764.6
# 1995  Cardiovascular Diseases  Heart Disease Mortality      747.5
# 1996  Cardiovascular Diseases  Heart Disease Mortality        NaN
# 1997  Cardiovascular Diseases  Heart Disease Mortality      769.3
# 1998  Cardiovascular Diseases  Heart Disease Mortality      526.9
# 1999  Cardiovascular Diseases  Heart Disease Mortality        NaN
#
#              data_value_unit  \
# 1990  per 100,000 population
# 1991  per 100,000 population
# 1992  per 100,000 population
# 1993  per 100,000 population
# 1994  per 100,000 population
# 1995  per 100,000 population
# 1996  per 100,000 population
# 1997  per 100,000 population
# 1998  per 100,000 population
# 1999  per 100,000 population
#
#                                         data_value_type  ... stratification1  \
# 1990  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1991  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1992  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1993  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1994  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1995  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1996  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1997  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1998  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
# 1999  Age-adjusted, Spatially Smoothed, 3-year Avera...  ...            Male
#
#      stratificationcategory2 stratification2 topicid locationid  \
# 1990          Race/Ethnicity           Black      T2      05001
# 1991          Race/Ethnicity           Black      T2      05003
# 1992          Race/Ethnicity           Black      T2      05005
# 1993          Race/Ethnicity           Black      T2      05009
# 1994          Race/Ethnicity           Black      T2      05011
# 1995          Race/Ethnicity           Black      T2      05013
# 1996          Race/Ethnicity           Black      T2      05015
# 1997          Race/Ethnicity           Black      T2      05017
# 1998          Race/Ethnicity           Black      T2      05019
# 1999          Race/Ethnicity           Black      T2      05021
#
#                                              location_1  \
# 1990  {'latitude': '34.289583', 'longitude': '-91.36...
# 1991  {'latitude': '33.194525', 'longitude': '-91.75...
# 1992  {'latitude': '36.284548', 'longitude': '-92.33...
# 1993  {'latitude': '36.306595', 'longitude': '-93.08...
# 1994  {'latitude': '33.471617', 'longitude': '-92.15...
# 1995  {'latitude': '33.561422', 'longitude': '-92.49...
# 1996  {'latitude': '36.337081', 'longitude': '-93.53...
# 1997  {'latitude': '33.272855', 'longitude': '-91.28...
# 1998  {'latitude': '34.05728', 'longitude': '-93.171...
# 1999  {'latitude': '36.364666', 'longitude': '-90.41...
#
#      :@computed_region_bxsw_vy29 :@computed_region_he4y_prf8  \
# 1990                          15                         946
# 1991                          15                         947
# 1992                          15                          10
# 1993                          15                         949
# 1994                          15                         950
# 1995                          15                         951
# 1996                          15                         952
# 1997                          15                         953
# 1998                          15                         954
# 1999                          15                         955
#
#      data_value_footnote_symbol data_value_footnote
# 1990                        NaN                 NaN
# 1991                        NaN                 NaN
# 1992                          ~   Insufficient Data
# 1993                          ~   Insufficient Data
# 1994                        NaN                 NaN
# 1995                        NaN                 NaN
# 1996                          ~   Insufficient Data
# 1997                        NaN                 NaN
# 1998                        NaN                 NaN
# 1999                          ~   Insufficient Data
#
# [10 rows x 21 columns]
